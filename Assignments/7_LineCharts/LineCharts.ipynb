# %% [markdown]
# # Line charts and dates

# %%
library(ggplot2)

# %%
enrollment <- read.csv("../../Data/enrollment.csv")

# %%
head(enrollment)
# Out:
#   Year Date     Enrollment
# 1 1967 1967-1-1 18067
# 2 1968 1968-1-1 19150
# 3 1969 1969-1-1 19618
# 4 1970 1970-1-1 20810
# 5 1971 1971-1-1 21541
# 6 1972 1972-1-1 21581

# %%
ggplot() + geom_line(data=enrollment, aes(y=Enrollment, x=Date, stat="identity"))
# Out:
# Warning message:
# “Ignoring unknown aesthetics: stat”geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
# plot without title
