# %% [markdown]
# # Recasting data
#
# Sometimes long data needs to be wide, and sometimes wide data needs to be long. I'll explain.
#
# You are soon going to discover that long before you can visualize data, you need to have it in a form that the visualization library can deal with. One of the ways that isn't immediately obvious is how your data is cast. Most of the data you will encounter will be wide -- each row will represent a single entity with multiple measures for that entity. So think of states. Your dataset could have population, average life expectancy and other demographic data.
#
# But what if your visualization library needs one row for each measure? That's where recasting your data comes in. We can use a library called `reshape2` to `melt` or `cast` the data, depending on what we need.
#
# So let's transform a dataset we've already used -- registered voters in Nebraska -- from wide data to long data and back again. First, we'll import the library and then open the data.

# %%
library(reshape2)

# %%
voters <- read.csv("../../Data/registeredvoters.csv")

# %%
head(voters)
# Out:
#   County   Republican10 Democrat10 Libertarian10 Nonpartisan10 Total10
# 1 Adams    10018        5536       6             2972          18532
# 2 Antelope  3005        1147       0              538           4690
# 3 Arthur     284          52       0               10            346
# 4 Banner     424          53       0               53            530
# 5 Blaine     314          56       0               24            394
# 6 Boone     2390        1156       0              408           3954
#   Republican16 Democrat16 Nonpartisan16 Libertarian16 Total16
# 1 10746        5027       3591          163           19527
# 2  3088         863        594           12            4557
# 3   286          37         15            3             341
# 4   427          38         73            7             545
# 5   310          43         29            2             384
# 6  2469         901        404           11            3785

# %% [markdown]
# Making data long, in most cases, is very, very easy. It's simple. We're going to create a new data frame called longvoters, and then `melt` our voters data into it. Then we'll run `head` and you'll see each measure gets it's own row -- so each county has 10 rows of data for it.

# %%
longvoters <- melt(voters)
head(longvoters)
# Out:
# Using County as id variables
#   County   variable     value
# 1 Adams    Republican10 10018
# 2 Antelope Republican10  3005
# 3 Arthur   Republican10   284
# 4 Banner   Republican10   424
# 5 Blaine   Republican10   314
# 6 Boone    Republican10  2390

# %% [markdown]
# But one problem that isn't immediately clear is where in spreadsheet world, a header like Republican10 and Republican16 makes sense, it doesn't here. We need fields to be able to have a County, a Party, a Year and then a count of those voters. So let's so some more worth with `mutate` and create those columns we need. And let's start exploring programmatic text manipulations. To simplify, we're going to use a library called `stringr` to get predictable patterns in our data.
#
# So if you look at the `variable` field, you see we have the party at the front and the year in the back and the year is always the last two characters of the field. The problem? We don't know WHICH characters those are. But `stringr` has a powerful tool called `str_sub` that can get us that, if we know one trick: That telling it to start at -2 means go to the end of the word and move backwards two characters.

# %%
library(stringr)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
longvoters %>% mutate(
    Year = str_sub(variable, start= -2),
)
# Out:
#     County       variable     value  Year
# 1   Adams        Republican10  10018 10
# 2   Antelope     Republican10   3005 10
# 3   Arthur       Republican10    284 10
# 4   Banner       Republican10    424 10
# 5   Blaine       Republican10    314 10
# 6   Boone        Republican10   2390 10
# 7   Box Butte    Republican10   4115 10
# 8   Boyd         Republican10   1036 10
# 9   Brown        Republican10   1663 10
# 10  Buffalo      Republican10  15768 10
# 11  Burt         Republican10   2521 10
# 12  Butler       Republican10   3044 10
# 13  Cass         Republican10   8216 10
# 14  Cedar        Republican10   3072 10
# 15  Chase        Republican10   1827 10
# 16  Cherry       Republican10   2945 10
# 17  Cheyenne     Republican10   4146 10
# 18  Clay         Republican10   2889 10
# 19  Colfax       Republican10   2364 10
# 20  Cuming       Republican10   3639 10
# 21  Custer       Republican10   5450 10
# 22  Dakota       Republican10   3577 10
# 23  Dawes        Republican10   3505 10
# 24  Dawson       Republican10   7666 10
# 25  Deuel        Republican10   1027 10
# 26  Dixon        Republican10   1887 10
# 27  Dodge        Republican10  10683 10
# 28  Douglas      Republican10 120973 10
# 29  Dundy        Republican10   1013 10
# 30  Fillmore     Republican10   2317 10
# ⋮   ⋮            ⋮            ⋮      ⋮
# 901 Nemaha       Total16        4563 16
# 902 Nuckolls     Total16        3162 16
# 903 Otoe         Total16       10447 16
# 904 Pawnee       Total16        1858 16
# 905 Perkins      Total16        1982 16
# 906 Phelps       Total16        6235 16
# 907 Pierce       Total16        4872 16
# 908 Platte       Total16       20116 16
# 909 Polk         Total16        3516 16
# 910 Red Willow   Total16        7239 16
# 911 Richardson   Total16        5669 16
# 912 Rock         Total16        1024 16
# 913 Saline       Total16        7830 16
# 914 Sarpy        Total16      108473 16
# 915 Saunders     Total16       14696 16
# 916 Scotts Bluff Total16       24139 16
# 917 Seward       Total16       10926 16
# 918 Sheridan     Total16        4066 16
# 919 Sherman      Total16        2010 16
# 920 Sioux        Total16         919 16
# 921 Stanton      Total16        3782 16
# 922 Thayer       Total16        3791 16
# 923 Thomas       Total16         506 16
# 924 Thurston     Total16        4529 16
# 925 Valley       Total16        2995 16
# 926 Washington   Total16       14322 16
# 927 Wayne        Total16        5236 16
# 928 Webster      Total16        2413 16
# 929 Wheeler      Total16         607 16
# 930 York         Total16       10013 16

# %% [markdown]
# If I really wanted to be correct, I could make those four digit years by adding 2000 to what the str_sub finds, but I also have to turn that into a number first.

# %%
longvoters %>% mutate(
    Year = 2000 + as.integer(str_sub(variable, start= -2)),
)
# Out:
#     County       variable     value  Year
# 1   Adams        Republican10  10018 2010
# 2   Antelope     Republican10   3005 2010
# 3   Arthur       Republican10    284 2010
# 4   Banner       Republican10    424 2010
# 5   Blaine       Republican10    314 2010
# 6   Boone        Republican10   2390 2010
# 7   Box Butte    Republican10   4115 2010
# 8   Boyd         Republican10   1036 2010
# 9   Brown        Republican10   1663 2010
# 10  Buffalo      Republican10  15768 2010
# 11  Burt         Republican10   2521 2010
# 12  Butler       Republican10   3044 2010
# 13  Cass         Republican10   8216 2010
# 14  Cedar        Republican10   3072 2010
# 15  Chase        Republican10   1827 2010
# 16  Cherry       Republican10   2945 2010
# 17  Cheyenne     Republican10   4146 2010
# 18  Clay         Republican10   2889 2010
# 19  Colfax       Republican10   2364 2010
# 20  Cuming       Republican10   3639 2010
# 21  Custer       Republican10   5450 2010
# 22  Dakota       Republican10   3577 2010
# 23  Dawes        Republican10   3505 2010
# 24  Dawson       Republican10   7666 2010
# 25  Deuel        Republican10   1027 2010
# 26  Dixon        Republican10   1887 2010
# 27  Dodge        Republican10  10683 2010
# 28  Douglas      Republican10 120973 2010
# 29  Dundy        Republican10   1013 2010
# 30  Fillmore     Republican10   2317 2010
# ⋮   ⋮            ⋮            ⋮      ⋮
# 901 Nemaha       Total16        4563 2016
# 902 Nuckolls     Total16        3162 2016
# 903 Otoe         Total16       10447 2016
# 904 Pawnee       Total16        1858 2016
# 905 Perkins      Total16        1982 2016
# 906 Phelps       Total16        6235 2016
# 907 Pierce       Total16        4872 2016
# 908 Platte       Total16       20116 2016
# 909 Polk         Total16        3516 2016
# 910 Red Willow   Total16        7239 2016
# 911 Richardson   Total16        5669 2016
# 912 Rock         Total16        1024 2016
# 913 Saline       Total16        7830 2016
# 914 Sarpy        Total16      108473 2016
# 915 Saunders     Total16       14696 2016
# 916 Scotts Bluff Total16       24139 2016
# 917 Seward       Total16       10926 2016
# 918 Sheridan     Total16        4066 2016
# 919 Sherman      Total16        2010 2016
# 920 Sioux        Total16         919 2016
# 921 Stanton      Total16        3782 2016
# 922 Thayer       Total16        3791 2016
# 923 Thomas       Total16         506 2016
# 924 Thurston     Total16        4529 2016
# 925 Valley       Total16        2995 2016
# 926 Washington   Total16       14322 2016
# 927 Wayne        Total16        5236 2016
# 928 Webster      Total16        2413 2016
# 929 Wheeler      Total16         607 2016
# 930 York         Total16       10013 2016

# %% [markdown]
# Okay, so I have one side of it. Now I need the other. Luckily, we can tell str_sub to start at a character and end at one. In this case, we want to start at 1 and end at -3.

# %%
longvoters %>% mutate(
    Year = 2000 + as.integer(str_sub(variable, start= -2)),
    Party = str_sub(variable, 1, -3),
)
# Out:
#     County       variable     value  Year Party
# 1   Adams        Republican10  10018 2010 Republican
# 2   Antelope     Republican10   3005 2010 Republican
# 3   Arthur       Republican10    284 2010 Republican
# 4   Banner       Republican10    424 2010 Republican
# 5   Blaine       Republican10    314 2010 Republican
# 6   Boone        Republican10   2390 2010 Republican
# 7   Box Butte    Republican10   4115 2010 Republican
# 8   Boyd         Republican10   1036 2010 Republican
# 9   Brown        Republican10   1663 2010 Republican
# 10  Buffalo      Republican10  15768 2010 Republican
# 11  Burt         Republican10   2521 2010 Republican
# 12  Butler       Republican10   3044 2010 Republican
# 13  Cass         Republican10   8216 2010 Republican
# 14  Cedar        Republican10   3072 2010 Republican
# 15  Chase        Republican10   1827 2010 Republican
# 16  Cherry       Republican10   2945 2010 Republican
# 17  Cheyenne     Republican10   4146 2010 Republican
# 18  Clay         Republican10   2889 2010 Republican
# 19  Colfax       Republican10   2364 2010 Republican
# 20  Cuming       Republican10   3639 2010 Republican
# 21  Custer       Republican10   5450 2010 Republican
# 22  Dakota       Republican10   3577 2010 Republican
# 23  Dawes        Republican10   3505 2010 Republican
# 24  Dawson       Republican10   7666 2010 Republican
# 25  Deuel        Republican10   1027 2010 Republican
# 26  Dixon        Republican10   1887 2010 Republican
# 27  Dodge        Republican10  10683 2010 Republican
# 28  Douglas      Republican10 120973 2010 Republican
# 29  Dundy        Republican10   1013 2010 Republican
# 30  Fillmore     Republican10   2317 2010 Republican
# ⋮   ⋮            ⋮            ⋮      ⋮    ⋮
# 901 Nemaha       Total16        4563 2016 Total
# 902 Nuckolls     Total16        3162 2016 Total
# 903 Otoe         Total16       10447 2016 Total
# 904 Pawnee       Total16        1858 2016 Total
# 905 Perkins      Total16        1982 2016 Total
# 906 Phelps       Total16        6235 2016 Total
# 907 Pierce       Total16        4872 2016 Total
# 908 Platte       Total16       20116 2016 Total
# 909 Polk         Total16        3516 2016 Total
# 910 Red Willow   Total16        7239 2016 Total
# 911 Richardson   Total16        5669 2016 Total
# 912 Rock         Total16        1024 2016 Total
# 913 Saline       Total16        7830 2016 Total
# 914 Sarpy        Total16      108473 2016 Total
# 915 Saunders     Total16       14696 2016 Total
# 916 Scotts Bluff Total16       24139 2016 Total
# 917 Seward       Total16       10926 2016 Total
# 918 Sheridan     Total16        4066 2016 Total
# 919 Sherman      Total16        2010 2016 Total
# 920 Sioux        Total16         919 2016 Total
# 921 Stanton      Total16        3782 2016 Total
# 922 Thayer       Total16        3791 2016 Total
# 923 Thomas       Total16         506 2016 Total
# 924 Thurston     Total16        4529 2016 Total
# 925 Valley       Total16        2995 2016 Total
# 926 Washington   Total16       14322 2016 Total
# 927 Wayne        Total16        5236 2016 Total
# 928 Webster      Total16        2413 2016 Total
# 929 Wheeler      Total16         607 2016 Total
# 930 York         Total16       10013 2016 Total

# %% [markdown]
# Two last things that are bothering me about our data? I don't like the number of voters being called `value` and we don't need `variable`. So we'll use dpylr to clean this up a bit.
#
# First we're going to use dpylr's `select` and a little R trick where you can use a negative sign to mean not this.
#
# Then, we'll use `rename`, which is backwards to me. If you read it, what it says is rename a column to Count and assign it the values of value. The reverse makes sense to me. Make values = Count, but `dplyr` does it the other way. If you get an error, you probably did it backwards (I did).

# %%
longvoters %>% mutate(
    Year = 2000 + as.integer(str_sub(variable, start= -2)),
    Party = str_sub(variable, 1, -3),
) %>% select (-c(variable)) %>% rename(Count=value)
# Out:
#     County       Count  Year Party
# 1   Adams         10018 2010 Republican
# 2   Antelope       3005 2010 Republican
# 3   Arthur          284 2010 Republican
# 4   Banner          424 2010 Republican
# 5   Blaine          314 2010 Republican
# 6   Boone          2390 2010 Republican
# 7   Box Butte      4115 2010 Republican
# 8   Boyd           1036 2010 Republican
# 9   Brown          1663 2010 Republican
# 10  Buffalo       15768 2010 Republican
# 11  Burt           2521 2010 Republican
# 12  Butler         3044 2010 Republican
# 13  Cass           8216 2010 Republican
# 14  Cedar          3072 2010 Republican
# 15  Chase          1827 2010 Republican
# 16  Cherry         2945 2010 Republican
# 17  Cheyenne       4146 2010 Republican
# 18  Clay           2889 2010 Republican
# 19  Colfax         2364 2010 Republican
# 20  Cuming         3639 2010 Republican
# 21  Custer         5450 2010 Republican
# 22  Dakota         3577 2010 Republican
# 23  Dawes          3505 2010 Republican
# 24  Dawson         7666 2010 Republican
# 25  Deuel          1027 2010 Republican
# 26  Dixon          1887 2010 Republican
# 27  Dodge         10683 2010 Republican
# 28  Douglas      120973 2010 Republican
# 29  Dundy          1013 2010 Republican
# 30  Fillmore       2317 2010 Republican
# ⋮   ⋮            ⋮      ⋮    ⋮
# 901 Nemaha         4563 2016 Total
# 902 Nuckolls       3162 2016 Total
# 903 Otoe          10447 2016 Total
# 904 Pawnee         1858 2016 Total
# 905 Perkins        1982 2016 Total
# 906 Phelps         6235 2016 Total
# 907 Pierce         4872 2016 Total
# 908 Platte        20116 2016 Total
# 909 Polk           3516 2016 Total
# 910 Red Willow     7239 2016 Total
# 911 Richardson     5669 2016 Total
# 912 Rock           1024 2016 Total
# 913 Saline         7830 2016 Total
# 914 Sarpy        108473 2016 Total
# 915 Saunders      14696 2016 Total
# 916 Scotts Bluff  24139 2016 Total
# 917 Seward        10926 2016 Total
# 918 Sheridan       4066 2016 Total
# 919 Sherman        2010 2016 Total
# 920 Sioux           919 2016 Total
# 921 Stanton        3782 2016 Total
# 922 Thayer         3791 2016 Total
# 923 Thomas          506 2016 Total
# 924 Thurston       4529 2016 Total
# 925 Valley         2995 2016 Total
# 926 Washington    14322 2016 Total
# 927 Wayne          5236 2016 Total
# 928 Webster        2413 2016 Total
# 929 Wheeler         607 2016 Total
# 930 York          10013 2016 Total

# %%
newlongvoters <- longvoters %>% mutate(
    Year = 2000 + as.integer(str_sub(variable, start= -2)),
    Party = str_sub(variable, 1, -3),
) %>% select (-c(variable)) %>% rename(Count=value)

# %% [markdown]
# Then, we can put it back together again by casting it using `dcast`. With `dcast`, we need to tell it which variable is our main identifier -- which is County -- and what the headers should be. We also have to tell it where the numbers should come from, since we blew it all apart. And you'll see, we've changed the data substantially, but it looks almost identical to the original dataset.

# %%
widevoters <- dcast(newlongvoters, County ~ Party+Year, value.var = "Count")
head(widevoters)
# Out:
#   County   Democrat_2010 Democrat_2016 Libertarian_2010 Libertarian_2016
# 1 Adams    5536          5027          6                163
# 2 Antelope 1147           863          0                 12
# 3 Arthur     52            37          0                  3
# 4 Banner     53            38          0                  7
# 5 Blaine     56            43          0                  2
# 6 Boone    1156           901          0                 11
#   Nonpartisan_2010 Nonpartisan_2016 Republican_2010 Republican_2016 Total_2010
# 1 2972             3591             10018           10746           18532
# 2  538              594              3005            3088            4690
# 3   10               15               284             286             346
# 4   53               73               424             427             530
# 5   24               29               314             310             394
# 6  408              404              2390            2469            3954
#   Total_2016
# 1 19527
# 2  4557
# 3   341
# 4   545
# 5   384
# 6  3785

# %% [markdown]
# ## Assignment
#
# Melt the [population estimates data](https://www.dropbox.com/s/u4s7rhcb37sk3cy/population.csv?dl=0) from assignment 3. Create long data, where each row is a single year for a single county, with columns for the state, county, year and estimate.
#
# #### Rubric
#
# 1. Did you import the data correctly?
# 2. Did you apply melt correctly?
# 3. Did you mutate/rename columns correctly?
# 4. Did you explain your steps using Markdown comments?
